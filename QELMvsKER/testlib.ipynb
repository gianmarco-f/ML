# %%
import myQMLfunctionsfolder as myQML

#Code to automatically reload the myQMLfunctions module when it is edited
# %load_ext autoreload
# %autoreload 2

# %%
myQML.helloworld()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 myQML.helloworld()
#
# AttributeError: module 'myQMLfunctionsfolder' has no attribute 'helloworld'
